# %%
pip install nltk
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 453.5 kB/s eta 0:00:03
#    -------------------- ------------------- 0.8/1.5 MB 714.3 kB/s eta 0:00:02
#    --------------------------- ------------ 1.0/1.5 MB 825.2 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 808.5 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 808.5 kB/s eta 0:00:01
# ...

# %%
pip install spacy
# Out:
# ...
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached pydantic_core-2.23.4-cp310-none-win_amd64.whl.metadata (6.7 kB)
# ...
#    ---------------------------------------- 0.0/12.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.2 MB 699.0 kB/s eta 0:00:17
#    - -------------------------------------- 0.5/12.2 MB 699.0 kB/s eta 0:00:17
#    -- ------------------------------------- 0.8/12.2 MB 671.3 kB/s eta 0:00:18
#    --- ------------------------------------ 1.0/12.2 MB 751.1 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.6/12.2 MB 987.0 kB/s eta 0:00:11
#    ------ --------------------------------- 2.1/12.2 MB 1.2 MB/s eta 0:00:09
# ...

# %%
python -m spacy download en_core_web_sm    # this is small model fast and use less memory
# python -m spacy download en_core_web_md    # this is medium sized model it is faster and larger size
# python -m spacy download en_core_web_lg    # this is a large model, it is even faster and very large size
# this is for english words
# Out:
#   Cell In[7], line 1
#     python -m spacy download en_core_web_sm    # this is small model fast and use less memory
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # we can't able to download english model in notebook, should need to download it in cmd
